# %%
import sys

# %%
print(sys.argv)
# Out:
# ['/Users/AnhHuynh/opt/anaconda3/lib/python3.9/site-packages/ipykernel_launcher.py', '--f=/Users/AnhHuynh/Library/Jupyter/runtime/kernel-v3a8c7194e32fd581ad793cfdedb5d09d643f8f738.json']

# %%
def function1():
  print('First function')

def function2():
  print('Second function')


arguments = sys.argv[1:]

if len(arguments) != 1:
  print(f'ERROR: 1 argument expected, {len(arguments)} give')
  sys.exit()
