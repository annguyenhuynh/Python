# %%
import os

# %%
with open("names.txt", "r") as f:
    content = f.read()
print(content)
# Out:
# Dave
# Jane
# Eddie
# Jimmy

# %%
with open("names.txt", "r") as f:
    print([line.strip() for line in f])
# Out:
# ['Dave', 'Jane', 'Eddie', 'Jimmy']

# %%
# Safe handling with try...except blco
try:
    f = open("name_list.txt")
    print(f.read())
except:
    print("File doesn't exist")
finally:
    f.close()
# Out:
# File doesn't exist

# %%
with open("names.txt", "a") as a:
    more_name = a.write('Neil')
print(more_name)

a.close()
# Out:
# 4

# %%
with open("names.txt", "r") as f:
    print(f.read())
# Out:
# Dave
# Jane
# Eddie
# Jimmy
# Neil

# %%
# Create the specified file, but return errors if the file exists

if not os.path.exists("an.txt"):
    f = open("an.txt", "x")
    f.close()

# %%
if os.path.exists("an.txt"):
    os.remove("an.txt")
else:
    print("The file doesn't exist")

# %%
names = ['Kim', 'An', 'Kai', 'Van', 'Phong']
with open("more_names.txt", "w") as t:
    for name in names:
        t.write(name + '\n')
